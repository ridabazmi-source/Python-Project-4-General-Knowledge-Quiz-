# %%
# ============================================================
# DecodeLabs Industrial Training Kit
# Python Programming - Project 4
# The General Knowledge Quiz
# ============================================================

print("=" * 50)
print("          GENERAL KNOWLEDGE QUIZ")
print("=" * 50)

# Initialize score
score = 0


# ------------------------------------------------------------
# Question 1
# ------------------------------------------------------------

answer = input("1. What is the capital of France? ").strip().lower()

if answer == "paris":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is Paris.")


# ------------------------------------------------------------
# Question 2
# ------------------------------------------------------------

answer = input("2. How many days are there in a week? ").strip().lower()

if answer == "7" or answer == "seven":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is 7.")


# ------------------------------------------------------------
# Question 3
# ------------------------------------------------------------

answer = input("3. What is the largest planet in our solar system? ").strip().lower()

if answer == "jupiter":
    print("Correct!")
    score += 1
else:
    print("Incorrect. The correct answer is Jupiter.")


# ------------------------------------------------------------
# Final Score
# ------------------------------------------------------------

print("\n" + "=" * 50)
print(f"Quiz Completed! Your final score is: {score}/3")
print("=" * 50)
# Out:
# ...
#           GENERAL KNOWLEDGE QUIZ
# ...
# 1. What is the capital of France? paris
# Correct!
# 2. How many days are there in a week? 7
# Correct!
# 3. What is the largest planet in our solar system? venus
# Incorrect. The correct answer is Jupiter.
#
# ...
# Quiz Completed! Your final score is: 2/3
# ...
